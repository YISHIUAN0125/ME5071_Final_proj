# %% [markdown]
# ## ME5071 Fundamental Theory and Engineering Application of Machine Vision Final Project
#
# All source code are avalible at https://github.com/YISHIUAN0125/ME5071_Final_proj.git

# %% [markdown]
# ###1. Install torchmetrics

# %%
# !pip install torchmetrics

# %% [markdown]
# ### 2. Clone final project repository and change the directory into ME5071_Final_Proj

# %%
# !git clone https://github.com/YISHIUAN0125/ME5071_Final_proj.git
# %cd ME5071_Final_proj

# %% [markdown]
# ### 3. Install the project

# %%
# !pip install .

# %% [markdown]
# ### 4. Mount to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 5. Scripts to execute evaluate.py
# Once you finished installed, the structure will be like this:
#
# ![Screenshot 2025-12-17 140650.png](data:image/png;base64,...)

# %%
# --weights path to model
# Refer to the following example to modified --explicit to point the path to the test data
# Easy
# !python tools/evaluate.py --weights /content/drive/MyDrive/影像工程概論期末/best_model.pth --explicit_path /content/drive/MyDrive/影像工程概論期末/test/easy

# %%
# Hard
# !python tools/evaluate.py --weights /content/drive/MyDrive/影像工程概論期末/best_model.pth --explicit_path /content/drive/MyDrive/影像工程概論期末/test/hard
